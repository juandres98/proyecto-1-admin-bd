# %%
import psycopg2
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
conn = psycopg2.connect(host = 'localhost', user= 'postgres', password ='26012616', dbname= 'sambil')
cursor = conn.cursor()

# %%
sql_query='select sexo,count(idpersona) as d from persona group by sexo'

df= pd.read_sql(sql_query,conn)

df.plot(kind='bar',x='sexo' , y='d')

# %%
sql_query='select * from compratl order by monto desc limit 10'

df= pd.read_sql(sql_query,conn)

df.plot(kind='bar',x='idcompra' , y='monto')

sql_query='select * from comprano order by monto desc limit 10'

df= pd.read_sql(sql_query,conn)

df.plot(kind='bar',x='idcomprano' , y='monto')

# %%
sql_query='select sum(monto) as m,idpersona from compratl group by idpersona order by sum(monto) desc limit 10'

df= pd.read_sql(sql_query,conn)e

df.plot(kind='bar',x='idpersona' , y='m')
# Out:
#   File "<ipython-input-9-350a1051dad7>", line 3
#     df= pd.read_sql(sql_query,conn)e
#                                    ^
# SyntaxError: invalid syntax

# %%
sql_query='select sexo,avg(edad) as edadprom from persona group by sexo'

df= pd.read_sql(sql_query,conn)

df.plot(kind='bar',x='sexo' , y='edadprom')

# %%
sql_query='select count(idpersona) as cantvisita,idpersona from entrada group by idpersona order by count(idpersona) asc limit 10'

df= pd.read_sql(sql_query,conn)

df.plot(kind='bar',x='idpersona' , y='cantvisita')

# %%
sql_query='select count(idpersona) as masvisita,idpersona from entrada group by idpersona limit 3'

df= pd.read_sql(sql_query,conn)

df.plot(kind='bar',x='idpersona' , y='masvisita')

# %%
sql_query='select count(idpersona) as ocupa , idpersona from ocupacion where estado=0 group by idpersona  order by count(idpersona) desc limit 5'

df= pd.read_sql(sql_query,conn)

df.plot(kind='bar',x='idpersona' , y='ocupa')
